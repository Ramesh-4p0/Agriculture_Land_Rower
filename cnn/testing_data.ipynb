# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# ##Test set Image Processing

# %% [markdown]
# ##Loading Model

# %%
cnn = tf.keras.models.load_model('tomato_255_32_cnn.h5')

# %% [markdown]
# ##Visualising and Performing Prediction on Single image

# %%
#Test Image Visualization
import cv2
image_path = r'Tomato\Test\ripe\IMG_20220511_090151.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ##Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(255,255))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 7s 7s/step

# %%
print(predictions)
# Out:
# [[6.6283914e-12 9.9999940e-01 5.6064550e-07 9.3896961e-13]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 1

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
class_names=["old","ripe","unripe"]
print("It's a {}".format(class_names[result_index]))
# Out:
# It's a ripe
